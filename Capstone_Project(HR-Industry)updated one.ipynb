# %% [markdown]
# # A brief understanding of the HR industry

# %% [markdown]
# # Part 1 - DEFINE

# %% [markdown]
# # --- 1 Define the problem ---

# %% [markdown]
# * In this project, you will have to put yourself in the shoes of an HR analytics expert and by leveraging the data provided, you are supposed to identify how salary is varying with respect to other considerable factors.
#
# * The dataset should be divided into test and train and you would have to use the training data to build the model and thereby apply it to test data to measure the performance and robustness of the model.

# %% [markdown]
# # General steps to be followed and tentative timelines:

# %% [markdown]
# 1.Understand the problem statement
#
# 2.Understand the data, make a valid business sense and write about it
#
# 3.Data analysis and interpretations
#
# 4.Data Cleaning and justification
#
# 5.Feature engineering(If needed)
#
# 6.Model building
#
# 7.(Justify why are you choosing a particular technique over others)
#
# 8.Cross-validation, performance check, and its explanation
#
# 9.Rework on different models, if needed
#
# 10.Visual interpretation
#
# 11.Results and Recommendations

# %% [markdown]
# Steps to be performed for successful completion of capstone project:
# Understand the data set - Feature description provided below. Check the number of variables that are normally distributed & explain Find out the correlation between variables using spearman rank correlation & explain Examine the relationship between categorical variables and the dependent variable & explain Clean and pre-process the data with other operations required, like, missing values, handling outliers, etc. as and when necessary & explain Apply ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable for the same & explain

# %% [markdown]
# # Feature Description

# %% [markdown]
# . Gender - talks of the gender - Male or female
#
# . Business - if the person has a business or no
#
# . Age - age of the person
#
# . Salary - CTC of the employee
#
# . Dependants - number of people dependant on the person
#
# . Months - duration of the person employed with the company
#
# . Calls - if the person has authority to make calls or not
#
# . Type - salary settlement type
#
# . Billing - Subscribed to billing plans or no
#
# . Unit sales - unit sale made by the person
#
# . Total sales - total sales made by the person
#
# . Rating - If he has been given a rating by a superior or no
#
# . Bonus - amount received by a person as bonus for sales
#
# . Base pay - Base pay of the employee
#
# . Unit price - The Unit price of a sale
#
# . Volume - volume allotted to a person
#
# . Opening balance - The opening balance of an employee
#
# . Low - lowest balance allotted to a person.
#
# . Closing Balance- The closing balance of an employee
#
# . Education- Educational background of an employee

# %% [markdown]
# # Main aspects

# %% [markdown]
# * Here we are going to do
# 1.how salary is varying with respect to other considerable factors.
#
# 2.dividing the dataset into test and train and using the training data to build the model and thereby apply it to test data to measure the performance and robustness of the model.
#
# 3.Perform Exploratory Data Analysis or (EDA).
#
# 4.Check Relation

# %%
# importing all the required libraries.
# getcwd gives the current working directory from where we want to read the data set.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
import datetime
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd()
# Out:
# '/Users/jagadeeshbodi'

# %%
#importing the data set using 'Pandas' library.
df=pd.read_csv('/Users/jagadeeshbodi/New_data_Set.csv')
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
# here we are displaying the first ten rows which have in dataset.
df.head(10)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
# 5    Male         0           No   Yes        Two year     Yes     No   23
# 6    Male         0          Yes    No        Two year     Yes     No   23
# 7  Female         0           No   Yes        One year     Yes     No   24
# 8  Female         1           No   Yes  Month-to-month     Yes    Yes   24
# 9    Male         0           No   Yes  Month-to-month     Yes     No   43
#
#        Salary     Base_pay       Bonus  Unit_Price    Volume  openingbalance  \
# ...

# %%
# here we are displaying the last ten rows which have in dataset.
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %%
# here we are finding info of the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
# here we are finding the data types of the dataset.
df.dtypes
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales        object
# Months              int64
# Education          object
# dtype: object

# %%
# here we are describing the given data with mean, std,min,max.
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
#converting 'total_Sales' column to numerical
pd.to_numeric(df['Total_Sales'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e5d99ab3e669> in <module>
#       1 #converting 'total_Sales' column to numerical
# ----> 2 pd.to_numeric(df['Total_Sales'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %% [markdown]
# * Here we can see that there is an error stating that there is a ' ' in some positions so checking for those positions

# %%
#Converting all the bank spaces in total sales to nan values 
df['Total_Sales']=df['Total_Sales'].replace(' ',np.nan)

# %%
df.shape
#there are 5000 rows and 20 columns in dataframe
# Out:
# (5000, 20)

# %%
df.size
#there are total of 100000 elements in data frame
# Out:
# 100000

# %%
#checking for duplicates in df
df=df.drop_duplicates(keep='first')
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %% [markdown]
# * We can see that no rows and columns have been removed so that means there are no duplicate values in the data frame

# %%
#checking for null values and summing them using 'sum()' function 
df.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %% [markdown]
# * As we can see there are around 1500+ nan values if we remove this value it may effect our data so we are going to fll them using Mean/Median To fill with Mean/Median we have to check for outliers AS the outliers may effect the mean

# %%
#Checking for outliers in the dataframe

plt.figure(figsize=(40,60))
df.plot(kind='box')

plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# * Here we can see there are outliers but we can't quite point them so we are going to check outliers individually

# %%
#checking for outliers in the data set
plt.figure(figsize=(20,10))

plt.subplot(131) #subplots used to plot three different plots in a row (place =1)
sns.boxplot(df['closingbalance']) #Boxplot for finding outliers 
plt.subplot(132) #subplots used to plot three different plots in a row (place=2)
sns.boxplot(df['low'])#Boxplot for finding outliers
plt.subplot(133) #subplots used to plot three different plots in a row (place=3)
sns.boxplot(df['Unit_Sales'])#Boxplot for finding outliers
# Out:
# <AxesSubplot:xlabel='Unit_Sales'>

# %%
plt.figure(figsize=(20,10)) #Setting size of graph

plt.subplot(131) #subplots used to plot three different plots in a row (place =1)
sns.boxplot(df['Age']) #Boxplot for finding outliers 
plt.subplot(132)#subplots used to plot three different plots in a row (place=2)
sns.boxplot(df['Salary'])#Boxplot for finding outliers
plt.subplot(133)#subplots used to plot three different plots in a row (place=3)
sns.boxplot(df['Base_pay'])#Boxplot for finding outliers
# Out:
# <AxesSubplot:xlabel='Base_pay'>

# %%
plt.figure(figsize=(20,10)) #Setting size of graph

plt.subplot(131)#subplots used to plot three different plots in a row (place =1)
sns.boxplot(df['Bonus'])#Boxplot for finding outliers 
plt.subplot(132)#subplots used to plot three different plots in a row (place=2)
sns.boxplot(df['Unit_Price'])#Boxplot for finding outliers 
plt.subplot(133)#subplots used to plot three different plots in a row (place=3)
sns.boxplot(df['Volume'])#Boxplot for finding outliers
# Out:
# <AxesSubplot:xlabel='Volume'>

# %%
plt.figure(figsize=(20,10)) #Setting size of graph

plt.subplot(121) #subplots used to plot three different plots in a row (place =1)
sns.boxplot(df['openingbalance'])#Boxplot for finding outliers 

plt.subplot(122)#subplots used to plot three different plots in a row (place=2)
sns.boxplot(df['Months'])#Boxplot for finding outliers
# Out:
# <AxesSubplot:xlabel='Months'>

# %% [markdown]
# * As we can see there are outliers in columns: openingbalance,Volume,UNit_price,Bonus,Age,Salary,Base_pay,closing_balance,low

# %% [markdown]
# * We can also see that there are large number of outliers and if we remove them around 30% of data will be removed, So we are going to be leave the outliers

# %% [markdown]
# * As there are Outliers in the the columns Total_Sales,openingbalance,Base_pay we are going to fill the nan with Median, AS Median is not sensitive to outliers as Mean is

# %%
#Replacing all the nan values with the median as the data has outliers
df['Total_Sales']=df['Total_Sales'].fillna(df['Total_Sales'].median())
df['openingbalance']=df['openingbalance'].fillna(df['openingbalance'].median())
df['Base_pay']=df['Base_pay'].fillna(df['Base_pay'].median())

# %%
#checking whether all the null values in the data are handled or not
df.isnull().sum()
# Out:
# Gender            0
# Business          0
# Dependancies      0
# Calls             0
# Type              0
# Billing           0
# Rating            0
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# Education         0
# dtype: int64

# %% [markdown]
# # 2.Checking For Normality of the columns

# %%
#performing nrmality check to verify whether the data is normally distributed or not
pg.normality(df)
# Out:
#                        W          pval  normal
# Business        0.440457  0.000000e+00   False
# Age             0.990820  1.691929e-17   False
# Salary          0.987063  5.153616e-21   False
# Base_pay        0.986482  1.727304e-21   False
# Bonus           0.987062  5.151575e-21   False
# Unit_Price      0.553489  0.000000e+00   False
# Volume          0.326129  0.000000e+00   False
# openingbalance  0.618410  0.000000e+00   False
# closingbalance  0.709553  0.000000e+00   False
# low             0.709145  0.000000e+00   False
# Unit_Sales      0.920096  1.401298e-45   False
# Months          0.901630  0.000000e+00   False

# %% [markdown]
# * As we can see from the data that no column is Normally distributed

# %%
#Checking the skewness of the columns
df.skew()
# Out:
# Business          1.855409
# Age              -0.259971
# Salary           -0.396042
# Base_pay         -0.365355
# Bonus            -0.396042
# Unit_Price        5.989663
# Volume            8.709735
# openingbalance    4.094791
# closingbalance    3.226368
# low               3.233667
# Unit_Sales       -0.225447
# Total_Sales       0.976270
# Months            0.257274
# dtype: float64

# %% [markdown]
# # 3.Finding out the correlation between variables using spearman rank correlation

# %% [markdown]
# * 1.The Spearman's rank-order correlation is the nonparametric version of the Pearson product-moment correlation.
# * 2.Spearman's correlation determines the strength and direction of the monotonic relationship between your two variables rather than the strength and direction of the linear relationship between your two variables, which is what Pearson's correlation determines.

# %%
from scipy.stats import spearmanr #importing spearmanr to check the correlation
rel=df.corr(method='spearman') #performing corelation analysis on all columns
print(rel)
fig=plt.subplots(figsize=(10,10))
sns.heatmap(rel,vmin=1,vmax=1,annot=True)#USing heat map to show the corelation between columns
# Out:
#                 Business       Age    Salary  Base_pay     Bonus  Unit_Price  \
# Business        1.000000 -0.008435 -0.018403 -0.019291 -0.018403   -0.019480
# Age            -0.008435  1.000000  0.202282  0.192531  0.202282    0.128266
# Salary         -0.018403  0.202282  1.000000  0.993744  1.000000    0.811713
# Base_pay       -0.019291  0.192531  0.993744  1.000000  0.993744    0.808168
# Bonus          -0.018403  0.202282  1.000000  0.993744  1.000000    0.811713
# Unit_Price     -0.019480  0.128266  0.811713  0.808168  0.811713    1.000000
# Volume         -0.002192 -0.039345 -0.390488 -0.390008 -0.390488   -0.324230
# openingbalance  0.004834  0.078137  0.171981  0.163022  0.171981    0.097258
# closingbalance -0.007485  0.440989  0.346498  0.339595  0.346498    0.263699
# low            -0.018103  0.202040  0.999859  0.993597  0.999859    0.812412
# Unit_Sales     -0.018363  0.202268  0.999997  0.993740  0.999997    0.811735
# ...

# %% [markdown]
# * As we can see that the salary has highest corelation with Unit_Sales,Low,Bonus,Base_pay

# %%
#Using LabelEncoder to convert the Education and Rating columns as they are necessary for machine learning algorithm
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() 
cols=['Education','Rating']
df[cols]=df[cols].apply(le.fit_transform)#applying LabelEncoder on the columnns
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing  Rating  \
# 0     Female         0           No   Yes  Month-to-month      No       1
# 1     Female         0           No   Yes  Month-to-month      No       1
# 2       Male         0           No   Yes  Month-to-month     Yes       0
# 3     Female         1           No   Yes  Month-to-month     Yes       1
# 4       Male         0           No   Yes  Month-to-month     Yes       1
# ...      ...       ...          ...   ...             ...     ...     ...
# 4995  Female         0           No   Yes  Month-to-month      No       0
# 4996    Male         0           No   Yes  Month-to-month     Yes       0
# 4997    Male         0           No   Yes  Month-to-month     Yes       0
# 4998    Male         1           No   Yes  Month-to-month     Yes       1
# 4999    Male         0          Yes   Yes        Two year     Yes       0
#
#       Age     Salary   Base_pay      Bonus  Unit_Price    Volume  \
# ...

# %%
#checking the unique values of Education and Rating
Education=df['Education'].unique() #Unique gives us the Unique values in the column Eduaction
print('Education',Education)
Rating=df['Rating'].unique()#Unique gives us the Unique values in the column Rating
print('Rating',Rating)
# Out:
# Education [1 2 0 3]
# Rating [1 0]

# %% [markdown]
# * We are going to check the skewness of the columns using Distplot

# %%
plt.figure(figsize=(20,10))
plt.subplot(131) #subplots used to plot three different plots in a row (place =1)
sns.distplot(df['Unit_Price']) #showing distributing plot for Unit_Price
plt.axvline(x=np.mean(df['Unit_Price']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Unit_Price'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Unit_Price'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(132) #subplots used to plot three different plots in a row (place =2)
sns.distplot(df['Volume']) #showing distributing plot for Volume
plt.axvline(x=np.mean(df['Volume']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Volume'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Volume'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(133) #subplots used to plot three different plots in a row (place =3)
sns.distplot(df['openingbalance']) #showing distributing plot for Openingbalance
plt.axvline(x=np.mean(df['openingbalance']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['openingbalance'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['openingbalance'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25)

# %%
plt.figure(figsize=(20,10))

plt.subplot(131) #subplots used to plot three different plots in a row (place =1)
sns.distplot(df['closingbalance'])#showing distributing plot for closinggbalance
plt.axvline(x=np.mean(df['closingbalance']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['closingbalance'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['closingbalance'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 
plt.subplot(132) #subplots used to plot three different plots in a row (place =2)
sns.distplot(df['low'])#showing distributing plot for low
plt.axvline(x=np.mean(df['low']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['low'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['low'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 
plt.subplot(133) #subplots used to plot three different plots in a row (place =3)
sns.distplot(df['Unit_Sales'])#showing distributing plot for Unit_Sales
plt.axvline(x=np.mean(df['Unit_Sales']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Unit_Sales'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Unit_Sales'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25)

# %%
plt.figure(figsize=(20,10))

plt.subplot(131) #subplots used to plot three different plots in a row (place =1)
sns.distplot(df['Months'])#showing distributing plot for Months
plt.axvline(x=np.mean(df['Months']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Months'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Months'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(132) #subplots used to plot three different plots in a row (place =2)
sns.distplot(df['Education'])#showing distributing plot for Education
plt.axvline(x=np.mean(df['Education']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Education'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Education'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(133) #subplots used to plot three different plots in a row (place =3)
sns.distplot(df['Rating'])#showing distributing plot for Rating
plt.axvline(x=np.mean(df['Rating']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Rating'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Rating'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25)

# %%
plt.figure(figsize=(20,10))

plt.subplot(131) #subplots used to plot three different plots in a row (place =1)
sns.distplot(df['Age'])#showing distributing plot for Months
plt.axvline(x=np.mean(df['Age']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Age'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Age'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(132) #subplots used to plot three different plots in a row (place =2)

sns.distplot(df['Bonus'],kde=True)
plt.axvline(x=np.mean(df['Bonus']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Bonus'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Bonus'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 


plt.subplot(133) #subplots used to plot three different plots in a row (place =3)
sns.distplot(df['Base_pay'])#showing distributing plot for Rating
plt.axvline(x=np.mean(df['Base_pay']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Base_pay'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Base_pay'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25)

# %%
plt.figure(figsize=(20,10))


sns.distplot(df['Salary'])#showing distributing plot for Education
plt.axvline(x=np.mean(df['Salary']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Salary'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Salary'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25)

# %% [markdown]
# * Here we saw that the columns which are normally distributed with reference to above plot are Salary,Bonus,Base_pay,Age So we are going to convert the remaining required columns into normal by using log Transformation and Squareroot transformation

# %%
df['Volume']=np.sqrt(df['Volume']) #Using Square root transformation to change volume
df['openingbalance']=np.log(df['openingbalance']) # Using Log transformation to convert openingbalance
df['closingbalance']=np.log(df['closingbalance'])# Using Log transformation to convert closingbalance

# %% [markdown]
# * 1.Removing the columns which are less corelated to salary
#
#   2.Removing the highly corelated columns can change there relation

# %% [markdown]
# * The columns which are less corelated with the salary are (closingbalance,openingbalance,volume)

# %%
plt.figure(figsize=(20,10))

plt.subplot(131)
sns.distplot(df['closingbalance'])
plt.axvline(x=np.mean(df['closingbalance']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['closingbalance'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['closingbalance'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(132)
sns.distplot(df['Volume'])
plt.axvline(x=np.mean(df['Volume']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['Volume'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['Volume'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25) 

plt.subplot(133)
sns.distplot(df['openingbalance'])
plt.axvline(x=np.mean(df['openingbalance']),c='r',ls='--',label='mean') #here we are providing the mean line to check the skewmness
plt.axvline(x=np.percentile(df['openingbalance'],25),c='black',ls='--',label='25th percentile')#here we are providing details for 25th percentile
plt.axvline(x=np.percentile(df['openingbalance'],75),c='black',ls='--',label='75th percentile')#here we are providing details for 75th percentile
plt.legend(fontsize=25)

# %% [markdown]
# * Here we can see that the closing balance and opening balance are little similar to normal distribution now

# %%
#checking for skewness again in the data frame to check whether the skewness of Volume, opening balance and closingbalance
df.skew()
# Out:
# Business          1.855409
# Rating            1.073441
# Age              -0.259971
# Salary           -0.396042
# Base_pay         -0.365355
# Bonus            -0.396042
# Unit_Price        5.989663
# Volume            3.293185
# openingbalance    0.236776
# closingbalance    0.143824
# low               3.233667
# Unit_Sales       -0.225447
# Total_Sales       0.976270
# Months            0.257274
# Education        -0.410609
# dtype: float64

# %%
#checking again for corelation after logtransformation
rel=df.corr(method='spearman') #performing corelation analysis on all columns
print(rel) #printing to find it numericaly
fig=plt.subplots(figsize=(10,10))
sns.heatmap(rel,vmin=1,vmax=1,annot=True)#USing heat map to show the corelation between columns
# Out:
#                 Business    Rating       Age    Salary  Base_pay     Bonus  \
# Business        1.000000  0.147498 -0.008435 -0.018403 -0.019291 -0.018403
# Rating          0.147498  1.000000 -0.009196  0.009708  0.009641  0.009708
# Age            -0.008435 -0.009196  1.000000  0.202282  0.192531  0.202282
# Salary         -0.018403  0.009708  0.202282  1.000000  0.993744  1.000000
# Base_pay       -0.019291  0.009641  0.192531  0.993744  1.000000  0.993744
# Bonus          -0.018403  0.009708  0.202282  1.000000  0.993744  1.000000
# Unit_Price     -0.019480  0.018395  0.128266  0.811713  0.808168  0.811713
# Volume         -0.002192 -0.014256 -0.039345 -0.390488 -0.390008 -0.390488
# openingbalance  0.004834 -0.003804  0.078137  0.171981  0.163022  0.171981
# closingbalance -0.007485 -0.020443  0.440989  0.346498  0.339595  0.346498
# low            -0.018103  0.009629  0.202040  0.999859  0.993597  0.999859
# ...

# %% [markdown]
# # Basic verifications

# %%
sns.countplot(df['Gender']) #provides you the number of males and females present in the dataframe
df['Gender'].value_counts() #NUmerical representation
# Out:
# Male      2528
# Female    2472
# Name: Gender, dtype: int64

# %%
sns.countplot(df['Type']) #checking the number of members having different types of salary payment
df['Type'].value_counts()#Numerical representation
# Out:
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: Type, dtype: int64

# %%
sns.countplot(df['Billing'])#checking how many people are billing 
df['Billing'].value_counts()# Numerical Representation
# Out:
# Yes    2956
# No     2044
# Name: Billing, dtype: int64

# %% [markdown]
# # how salary is varying with respect to other considerable factors.
# Using spearman corelation we found out that the Salary has good corelation with BOnus,Base_pay,Unit_Sales,Total_Sales,Low we are going to show there relation ship now

# %%
sns.scatterplot(df['Bonus'],df['Salary']) # checking relation between salary and Bonus
# Out:
# <AxesSubplot:xlabel='Bonus', ylabel='Salary'>

# %%
sns.scatterplot(df['Unit_Sales'],df['Salary'])## checking relation between salary and Unitsales
# Out:
# <AxesSubplot:xlabel='Unit_Sales', ylabel='Salary'>

# %% [markdown]
# here we can see monotonic increase (as UNit_Sales increases Salary Increases) so it means that the the person who has high unit sales should be provided with better salary

# %%
sns.scatterplot(df['Base_pay'],df['Salary'])## checking relation between salary and Base_pay
# Out:
# <AxesSubplot:xlabel='Base_pay', ylabel='Salary'>

# %% [markdown]
# Here Base_pay and salary are in positive linear corealtion (as salary increases basepay increases)

# %%
sns.scatterplot(df['Salary'],df['low']) # checking relation between salary and low
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='low'>

# %% [markdown]
# Here you can see that there is monotonic increase (As Salary increases the Low always increase)

# %%
sns.scatterplot(df['Salary'],df['Unit_Price']) # checking relation between salary and Unit_price
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Unit_Price'>

# %% [markdown]
# * As the spearman Corelation suggests there is no relation between Salary and Unit_price

# %% [markdown]
# # Apply ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable for the same.

# %%
#Taking all required numerical values into a new dataframe to model 
df1=df[['Business','Age','Salary','Base_pay','Bonus','Unit_Price','Volume','openingbalance','closingbalance','low','Unit_Sales','Total_Sales','Months','Education']]
df1.head() #printig the top  5 rows
# Out:
#    Business  Age   Salary  Base_pay     Bonus  Unit_Price       Volume  \
# 0         0   18  5089.00  2035.600  254.4500        3.77  4607.233443
# 1         0   19  5698.12  2279.248  284.9060        3.74  3234.625171
# 2         0   22  5896.65  2358.660  294.8325        3.89  4331.397003
# 3         1   21  6125.12  2450.048  306.2560        4.35  8132.072307
# 4         0   23  6245.00  2498.000  312.2500        4.34  5183.454447
#
#    openingbalance  closingbalance   low  Unit_Sales Total_Sales  Months  \
# 0        1.321756        1.324419  3.65       18.25        18.8       0
# 1        1.348073        1.302913  3.65       18.40       18.85       0
# 2        1.442202        1.456287  3.72       18.70        18.9       0
# 3        1.449269        1.460938  3.83       18.75          19       0
# 4        1.566530        1.483875  4.08       18.80       19.05       1
#
#    Education
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
x=df1.drop('Salary',axis=1) #taking all the columns except salary as SAlary is dependent variable

# %%
x_list=list(x.columns) #listing out the columns  which we are taking in x as independent variables
x_list
# Out:
# ['Business',
#  'Age',
#  'Base_pay',
#  'Bonus',
#  'Unit_Price',
#  'Volume',
#  'openingbalance',
#  'closingbalance',
#  'low',
#  'Unit_Sales',
#  'Total_Sales',
#  'Months',
#  'Education']

# %%
y=df1['Salary'] #Placing Salary as an dependent variable  for model
y
# Out:
# 0         5089.00
# 1         5698.12
# 2         5896.65
# 3         6125.12
# 4         6245.00
#           ...
# 4995    180696.80
# 4996    185685.90
# 4997    192636.80
# 4998    195970.70
# 4999    199970.74
# Name: Salary, Length: 5000, dtype: float64

# %%
# splitting x and y into test and train using train_test_split
# for processing the test into the model  
from sklearn.model_selection import train_test_split #importing train_test_split from model_selection
from sklearn import metrics
#splitting X and Y into train and test splits
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.33,random_state=10) #HEre we are splitting it with 33% test and 67% train

#Checking how many rows and columns are present in train and test of x and y 

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3350, 13)
# (1650, 13)
# (3350,)
# (1650,)

# %% [markdown]
# Checking for which Algorithm to use: 1.Linear regressor : we can't use linear regression because the values are non paramteric and non-linear 2.Logistic regression: we can't use logistic regression because the values are not binary 3.decision tree Regression: we can use it but we can't be sure it is good for our model 4.Random Forest regressino: we can use it too but we can't be sure it is good for our model

# %% [markdown]
# * performing test to find which model is better

# %%
# importing libraries for perforimng machine learning
from sklearn.ensemble import RandomForestRegressor #importing RandomForestRegressor as the model is numerical
from sklearn.metrics import mean_squared_error #Importing Mean_squarred_error to find the error
from sklearn.metrics import r2_score ##importing r2_score t check the precision of model
from sklearn.tree import DecisionTreeRegressor #importing RandomForestRegressor as the model is numerical

# %%
DTR=DecisionTreeRegressor(max_depth=3) #calling decision tree
DTR.fit(x_train,y_train) #fitting it into training data of  x and y
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
print('DecisionTree_train:',DTR.score(x_train,y_train)) #finding out the trainning score of both x and y 
print('DecisionTree_test:',DTR.score(x_test,y_test)) #finding out the testing score of both x and y
# Out:
# DecisionTree_train: 0.9617197628021664
# DecisionTree_test: 0.9643947886935025

# %%
RFREG= RandomForestRegressor(n_estimators= 100) #calling Randomforestregressor and the n_estimator means number of trees
RFREG.fit(x_train, y_train) #fitting it into training data of x and y
print('RandomForestRegressor:',RFREG.score(x_train,y_train)) #finding out the trainning score of both x and y 
print('RandomForestRegressor:',RFREG.score(x_test,y_test))#finding out the testing score of both x and y
# Out:
# RandomForestRegressor: 0.9999815948076054
# RandomForestRegressor: 0.9999371378384343

# %% [markdown]
# Here we can clearly see that the RandomforestRegressor has better score than Decision Tree so we are going to use Randomforest Regressor

# %% [markdown]
# # Starting with RandomForestRegressor

# %%
#Before starting we have to decide the best n_estimator and Random_state for model
RFREG.fit(x_train, y_train) #Fitting it to training data of x and y
for i in range(4,20): #creating a for loop for estimator 
    for n in range (1,50): #creating a for loop for Random_state       
        RFREG= RandomForestRegressor(n_estimators=i,random_state=n) 
        RFREG.fit(x_train,y_train)        
        test=RFREG.score(x_test,y_test) #Adding the scoring values to test
        train=RFREG.score(x_train,y_train)#Adding the scoring values to train
        
        if(test>train): #providing a condition for test score to be greater than train score as test shoukd always be higher than train
            print(f'estimator: {i},random_state: {n}') #printing the values which are good          
            print('test:',test) #printing the test values which are good  
            print('train',train)#printing the train values which are good
# Out:
# estimator: 4,random_state: 1
# test: 0.999862482104227
# train 0.9998399539943617
# estimator: 4,random_state: 4
# test: 0.999521863433367
# train 0.9992229716790456
# estimator: 4,random_state: 7
# test: 0.9999647532950349
# train 0.999940585534374
# estimator: 4,random_state: 13
# test: 0.9999240988301364
# train 0.9998378095626128
# estimator: 4,random_state: 36
# test: 0.9998526180058857
# train 0.9998049684897344
# estimator: 4,random_state: 43
# test: 0.9998555270013952
# train 0.9998541386582033
# estimator: 5,random_state: 4
# test: 0.9996686825270349
# train 0.999497919424638
# estimator: 5,random_state: 7
# test: 0.9999661510992399
# train 0.9999567170979918
# estimator: 5,random_state: 13
# test: 0.9998866266698846
# train 0.9998192861602694
# estimator: 5,random_state: 20
# test: 0.9999447112341106
# train 0.9999399309005178
# estimator: 5,random_state: 31
# test: 0.9999517019281621
# train 0.999946286560221
# estimator: 5,random_state: 36
# test: 0.999911033359241
# ...

# %% [markdown]
# Here for estimator 17 and random_state=35 as we are getting better test value greater than train value so we are going to take these values

# %%
RFREG= RandomForestRegressor(n_estimators=17,random_state=35) #calling Randomforestregressor with n_estimator=17 and random_state=35
RFREG.fit(x_train,y_train)#fitting data
y_pred= RFREG.predict((x_test)) # predicting the score with x_test
meanSquaredError=metrics.mean_squared_error(y_test, y_pred) #performing mean_squarred_error
print("MSE:", meanSquaredError) #printing mean_squared_error
rootMeanSquaredError = np.sqrt(meanSquaredError) #performing Root_mean_squarred_error
print("RMSE:", rootMeanSquaredError) #printing Root_mean_squarred_error
r2=r2_score(y_test,y_pred) #performing r2_score
print('r2_score_train :', r2) #printing r2_score
# Out:
# MSE: 33702.782432614535
# RMSE: 183.5831757885633
# r2_score_train : 0.9999469986100307

# %%
#we are going to check whether the values of the predicted and normal values are similar or not
t_1=pd.DataFrame({'Actual' :y_test,'Pred' : y_pred})
print(t_1)
# Out:
#             Actual           Pred
# 245    57883.44624   57881.841919
# 4493  131156.47240  131105.283112
# 4583  133615.53540  133610.816394
# 2242   97647.63276   97648.460394
# 3407  112067.74690  112052.810506
# ...            ...            ...
# 2759  103686.52410  103683.649418
# 1287   84470.24398   84476.718006
# 3228  109749.00210  109758.293694
# 3261  110232.16230  110217.626965
# 895    78294.41021   78320.788578
#
# [1650 rows x 2 columns]

# %% [markdown]
# Finding out whether the model is accurate or not

# %%
# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 39.52 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 99.93 %.

# %% [markdown]
# Here we can see that accuracy is 99.93% so we don't have to check for any other model

# %% [markdown]
# # Feature importance

# %%
RFREG.feature_importances_ #calling feature importance adn checking the feature importance
# Out:
# array([1.14858376e-06, 1.62503075e-03, 9.86828631e-02, 5.47817585e-01,
#        1.02332356e-03, 1.52915369e-05, 1.01926545e-02, 3.12221974e-03,
#        3.66383150e-03, 3.08997606e-01, 2.35878753e-02, 1.24743974e-03,
#        2.31309578e-05])

# %%
#Assigning it to importance
importance = RFREG.feature_importances_

x_values = list(range(len(importance))) 

# summarize feature importance
# plot feature importance
plt.figure(figsize=(30,30))
plt.bar(x_list, importance)
plt.xticks(x_values,rotation ='vertical',fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Importance',fontsize=25,c='r')
plt.xlabel('Variable',fontsize=25,c='r') 
plt.title('Variable Importances',fontsize=30,c='r')

plt.show()

# %% [markdown]
# * The above plot shows us that The important features 1.Bonus 2.Unit_Sales 3.Base_pay

# %% [markdown]
# * Inference:
#     So we have to give the salary to the people  who are making good unit_sales
#     with greater salary we also have to provide the greater bonus to staff to keep them happy
#     and basically salary means base pay also increases
