# %% [markdown]
# # A brief understanding of the HR industry

# %% [markdown]
# # Part 1 - DEFINE

# %% [markdown]
# # --- 1 Define the problem ---

# %% [markdown]
# In this project, you will have to put yourself in the shoes of an HR analytics expert and by leveraging the data provided, you are supposed to identify how salary is varying with respect to other considerable factors.
#
# The dataset should be divided into test and train and you would have to use the training data to build the model and thereby apply it to test data to measure the performance and robustness of the model.

# %% [markdown]
# # General steps to be followed and tentative timelines:

# %% [markdown]
# 1.Understand the problem statement
#
# 2.Understand the data, make a valid business sense and write about it
#
# 3.Data analysis and interpretations
#
# 4.Data Cleaning and justification
#
# 5.Feature engineering(If needed)
#
# 6.Model building
#
# 7.(Justify why are you choosing a particular technique over others)
#
# 8.Cross-validation, performance check, and its explanation
#
# 9.Rework on different models, if needed
#
# 10.Visual interpretation
#
# 11.Results and Recommendations

# %% [markdown]
# Steps to be performed for successful completion of capstone project:
#
# Understand the data set - Feature description provided below.
# Check the number of variables that are normally distributed & explain
# Find out the correlation between variables using spearman rank correlation & explain
# Examine the relationship between categorical variables and the dependent variable & explain
# Clean and pre-process the data with other operations required, like, missing values, handling outliers, etc. as and when necessary & explain
# Apply ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable for the same & explain

# %% [markdown]
# # Feature Description

# %% [markdown]
# . Gender - talks of the gender - Male or female
#
# . Business - if the person has a business or no
#
# . Age - age of the person
#
# . Salary - CTC of the employee
#
# . Dependants - number of people dependant on the person
#
# . Months - duration of the person employed with the company
#
# . Calls - if the person has authority to make calls or not
#
# . Type - salary settlement type
#
# . Billing - Subscribed to billing plans or no
#
# . Unit sales - unit sale made by the person
#
# . Total sales - total sales made by the person
#
# . Rating - If he has been given a rating by a superior or no
#
# . Bonus - amount received by a person as bonus for sales
#
# . Base pay - Base pay of the employee
#
# . Unit price - The Unit price of a sale
#
# . Volume - volume allotted to a person
#
# . Opening balance - The opening balance of an employee
#
# . Low - lowest balance allotted to a person.
#
# . Closing Balance- The closing balance of an employee
#
# . Education- Educational background of an employee

# %%
# importing all the required libraries.
# getcwd gives the current working directory from where we want to read the data set.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd()
# Out:
# '/Users/jagadeeshbodi'

# %% [markdown]
# # Part 2 - Discover

# %% [markdown]
# # --- 2 Load the data ---

# %%
# here we are importing the given hr data set which is in csv format.
df=pd.read_csv('/Users/jagadeeshbodi/New_data_Set.csv')
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %% [markdown]
# # 3.Preparing the data frame for further analysis. Cleaning, molding in convinient manner to see them fit.

# %%
# here we are displaying the first ten rows which have in dataset.
df.head(10)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
# 5    Male         0           No   Yes        Two year     Yes     No   23
# 6    Male         0          Yes    No        Two year     Yes     No   23
# 7  Female         0           No   Yes        One year     Yes     No   24
# 8  Female         1           No   Yes  Month-to-month     Yes    Yes   24
# 9    Male         0           No   Yes  Month-to-month     Yes     No   43
#
#        Salary     Base_pay       Bonus  Unit_Price    Volume  openingbalance  \
# ...

# %%
# here we are displaying the last ten rows which have in dataset.
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %%
# here we are finding info of the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
# here we are finding the data types of the dataset.
df.dtypes
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales        object
# Months              int64
# Education          object
# dtype: object

# %%
# here we are describing the given data with mean, std,min,max.
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
# here we are describing the mean value from data set
df.mean()
# Out:
# Business          1.600000e-01
# Age               5.186500e+01
# Salary            9.982193e+04
# Base_pay          4.004619e+04
# Bonus             4.991096e+03
# Unit_Price        5.125852e+01
# Volume            6.761260e+06
# openingbalance    4.392202e+01
# closingbalance    4.357783e+01
# low               4.303413e+01
# Unit_Sales        6.484151e+01
# Months            3.218480e+01
# dtype: float64

# %%
# here we are describing the max value from data set
df.max()
# Out:
# Gender                  Male
# Business                   1
# Dependancies             Yes
# Calls                    Yes
# Type                Two year
# Billing                  Yes
# Rating                   Yes
# Age                       88
# Salary             199970.74
# Base_pay           79988.296
# Bonus               9998.537
# Unit_Price        629.511067
# Volume             320868400
# openingbalance    313.903904
# closingbalance    313.688694
# low               312.432438
# Unit_Sales            118.75
# Months                    72
# Education                 PG
# dtype: object

# %%
# here we are describing the min value from data set
df.min()
# Out:
# Gender                    Female
# Business                       0
# Dependancies                  No
# Calls                         No
# Type              Month-to-month
# Billing                       No
# Rating                        No
# Age                           18
# Salary                    5089.0
# Base_pay                  2035.6
# Bonus                     254.45
# Unit_Price                  1.44
# Volume                         0
# openingbalance              3.68
# closingbalance              3.68
# low                         3.65
# Unit_Sales                 18.25
# Months                         0
# Education             Graduation
# dtype: object

# %%
# here we are finding the size of the data.
df.size
# Out:
# 100000

# %%
#finding categorical data is available in the given data set.
df.select_dtypes('object')
# Out:
#       Gender Dependancies Calls            Type Billing Rating Total_Sales  \
# 0     Female           No   Yes  Month-to-month      No    Yes        18.8
# 1     Female           No   Yes  Month-to-month      No    Yes       18.85
# 2       Male           No   Yes  Month-to-month     Yes     No        18.9
# 3     Female           No   Yes  Month-to-month     Yes    Yes          19
# 4       Male           No   Yes  Month-to-month     Yes    Yes       19.05
# ...      ...          ...   ...             ...     ...    ...         ...
# 4995  Female           No   Yes  Month-to-month      No     No
# 4996    Male           No   Yes  Month-to-month     Yes     No
# 4997    Male           No   Yes  Month-to-month     Yes     No
# 4998    Male           No   Yes  Month-to-month     Yes    Yes
# 4999    Male          Yes   Yes        Two year     Yes     No
#
#                 Education
# 0     High School or less
# 1     High School or less
# 2     High School or less
# ...

# %%
# checking whether null values are present or not.
df.isna()
# Out:
#       Gender  Business  Dependancies  Calls   Type  Billing  Rating    Age  \
# 0      False     False         False  False  False    False   False  False
# 1      False     False         False  False  False    False   False  False
# 2      False     False         False  False  False    False   False  False
# 3      False     False         False  False  False    False   False  False
# 4      False     False         False  False  False    False   False  False
# ...      ...       ...           ...    ...    ...      ...     ...    ...
# 4995   False     False         False  False  False    False   False  False
# 4996   False     False         False  False  False    False   False  False
# 4997   False     False         False  False  False    False   False  False
# 4998   False     False         False  False  False    False   False  False
# 4999   False     False         False  False  False    False   False  False
#
#       Salary  Base_pay  Bonus  Unit_Price  Volume  openingbalance  \
# ...

# %%
#we are checking if there are any rows with NaN
nan_df=df[df.isna().any(axis=1)]
nan_df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 37      Male         0          Yes   Yes        Two year      No     No   36
# 97      Male         0           No   Yes        One year     Yes     No   40
# 124     Male         0           No   Yes  Month-to-month      No     No   41
# 125     Male         0          Yes   Yes        Two year      No     No   42
# 126   Female         0           No   Yes        One year     Yes     No   42
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df=df.interpolate()
# We use the interpolate() function. Pandas fills them in nicely using the midpoints between the points.

# %%
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
# checking whether null values are present or not
nulls = df.isnull().sum()
nulls[nulls > 0]
# Out:
# Total_Sales    8
# dtype: int64

# %%
df = df.replace(r'^\s*$', np.NaN, regex=True)
# replace field that's entirely space (or empty) with NaN

# %%
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
# checking whether null values are present or not
nulls = df.isnull().sum()
nulls[nulls > 0]
# still there are 16 null values in the dataset
# Out:
# Total_Sales    16
# dtype: int64

# %%
# displaying the total NaN values in dataframe
nan_df=df[df.isna().any(axis=1)]
nan_df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 37      Male         0          Yes   Yes        Two year      No     No   36
# 97      Male         0           No   Yes        One year     Yes     No   40
# 170   Female         0          Yes   Yes  Month-to-month     Yes     No   44
# 227     Male         0          Yes   Yes        One year      No     No   45
# 315     Male         0           No   Yes  Month-to-month      No     No   47
# 2650  Female         0           No   Yes  Month-to-month      No     No   64
# 4027  Female         0          Yes   Yes        Two year     Yes     No   51
# 4767  Female         0           No   Yes        Two year     Yes     No   56
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# ...

# %%
# here we are using mode function to fill NaN values
df['Total_Sales'] = df['Total_Sales'].fillna(df['Total_Sales'].mode()[0])

# %%
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
# displaying info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        5000 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  5000 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
# here we are converting the data type of Total sales from object to float 
df['Total_Sales'] = df['Total_Sales'].astype(float)
print(df.dtypes)
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# Education          object
# dtype: object

# %%
# counting the values for type column(salary settlement type)
df['Type'].value_counts()
# Out:
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: Type, dtype: int64

# %%
# counting the values for Billing column
df['Billing'].value_counts()
# Out:
# Yes    2956
# No     2044
# Name: Billing, dtype: int64

# %%
# counting the values for rating column
df['Rating'].value_counts()
# Out:
# No     3682
# Yes    1318
# Name: Rating, dtype: int64

# %%
# counting the values for calls column
df['Calls'].value_counts()
# Out:
# Yes    4539
# No      461
# Name: Calls, dtype: int64

# %%
# counting the values for Total sales column
df['Total_Sales'].value_counts()
# Out:
# 19.45      22
# 20.15       6
# 19.75       6
# 20.20       6
# 20.05       5
#            ..
# 445.95      1
# 710.05      1
# 5610.70     1
# 109.50      1
# 5730.70     1
# Name: Total_Sales, Length: 4705, dtype: int64

# %%
# counting the values for unitsales column
df['Unit_Sales'].value_counts()
# Out:
# 19.85     36
# 20.05     35
# 19.90     32
# 19.70     32
# 20.25     32
#           ..
# 31.00      1
# 97.20      1
# 78.40      1
# 62.85      1
# 103.80     1
# Name: Unit_Sales, Length: 1434, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# let us visualize our data to get a much clearer picture of the data significant features.

# %%
# counting the value counts of education 
df['Education'].value_counts()
# Out:
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: Education, dtype: int64

# %%
# plotting the results.
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')
ax=sns.countplot('Education',data=df,palette='copper')
ax.set_xlabel(xlabel="Education",fontsize=20)
ax.set_ylabel(ylabel="Education count",fontsize=20)
ax.set_title(label="Education count of staff members",fontsize=22)
plt.show()

# %% [markdown]
# as per above visualization intermediate and high school level are very less members are there in staff

# %%
# counting the valuecounts of gender
df['Gender'].value_counts()
# Out:
# Male      2528
# Female    2472
# Name: Gender, dtype: int64

# %%
# plotting the results
plt.figure(figsize=(10,7))
plt.style.use('fivethirtyeight')
ax=sns.countplot('Gender',data=df)
ax.set_xlabel(xlabel="Gender",fontsize=20)
ax.set_ylabel(ylabel="Gender count",fontsize=20)
ax.set_title(label="Gender count of staff members",fontsize=22)
plt.show()

# %% [markdown]
# both males and females are similarly equal but males are quite high

# %%
# using cross tab function for comparing two columns
pd.crosstab(df.Dependancies,df.Gender)
# Out:
# Gender        Female  Male
# Dependancies
# No              1756  1768
# Yes              716   760

# %%
# plotting the results
plt.figure(figsize=(14,6))
plt.title('Total Dependancies over Gender')
sns.countplot(df['Dependancies'],hue=df.Gender)
# Out:
# <AxesSubplot:title={'center':'Total Dependancies over Gender'}, xlabel='Dependancies', ylabel='count'>

# %% [markdown]
# males are having more dependancies compared to females

# %%
# using cross tab function for comparing two columns
pd.crosstab(df.Gender,df.Business)
# Out:
# Business     0    1
# Gender
# Female    2071  401
# Male      2129  399

# %%
# plotting the results
plt.figure(figsize=(14,6))
plt.title('Total Business owned by Gender')
sns.countplot(df['Business'],hue=df.Gender)
# Out:
# <AxesSubplot:title={'center':'Total Business owned by Gender'}, xlabel='Business', ylabel='count'>

# %% [markdown]
# males and females have equal business

# %%
# counting the values of age column 
df['Age'].value_counts()
# Out:
# 50    256
# 53    254
# 55    248
# 54    245
# 51    244
#      ...
# 88      2
# 82      1
# 85      1
# 80      1
# 79      1
# Name: Age, Length: 65, dtype: int64

# %%
# plotting the results
plt.figure(figsize=(14,6))
plt.title('Age of staff members')
sns.countplot(df['Age'])
# Out:
# <AxesSubplot:title={'center':'Age of staff members'}, xlabel='Age', ylabel='count'>

# %% [markdown]
# Age group lies between 50 to 57 are more in staff members, compared to other age groups

# %%
# using cross tab function for comparing two columns
pd.crosstab(df.Age,df.Gender)
# Out:
# Gender  Female  Male
# Age
# 18           2     0
# 19           3     0
# 20           2     2
# 21           5     3
# 22           3     3
# ..         ...   ...
# 79           1     0
# 80           0     1
# 82           1     0
# 85           0     1
# 88           0     2
#
# [65 rows x 2 columns]

# %%
# plotting the results
plt.figure(figsize=(14,6))
plt.title('Age and Gender of staff members')
sns.countplot(df['Age'],hue=df.Gender)
# Out:
# <AxesSubplot:title={'center':'Age and Gender of staff members'}, xlabel='Age', ylabel='count'>

# %%
# using cross tab function for comparing two columns
pd.crosstab(df.Salary,df.Education)
# Out:
# Education  Graduation  High School or less  Intermediate  PG
# Salary
# 5089.00             0                    1             0   0
# 5698.12             0                    1             0   0
# 5896.65             0                    1             0   0
# 6125.12             0                    1             0   0
# 6245.00             0                    1             0   0
# ...               ...                  ...           ...  ..
# 180696.80           0                    0             0   1
# 185685.90           0                    0             0   1
# 192636.80           0                    0             0   1
# 195970.70           0                    0             0   1
# 199970.74           0                    0             0   1
#
# [5000 rows x 4 columns]

# %%
# counting the values of month column
df['Months'].value_counts()
# Out:
# 1     436
# 72    269
# 2     180
# 3     141
# 4     130
#      ...
# 59     38
# 39     36
# 36     33
# 44     32
# 0       8
# Name: Months, Length: 73, dtype: int64

# %%
months= [month for month,df in df.groupby('Months')]
# plotting graph for number of months employees worked in industry     
plt.figure(figsize=(18,8))
plt.xticks(months)# gives plot value for each month
plt.xlabel('Months')
plt.ylabel('count')
plt.grid()
plt.plot(months,df.groupby(['Months']).count())

# %%
# here displaying all the int and float types in the form of histogram
num_bins=13
df.hist(bins=num_bins,figsize=(20,18))
plt.savefig("df_histogram_plots")
plt.show()

# %%
# plotting distribution plot for salary
sns.distplot( a=df['Salary'], hist=True, kde=False, rug=False )
# Out:
# <AxesSubplot:xlabel='Salary'>

# %% [markdown]
# # Here i try to add salary_age_realtion column by using salary,basepay and age columns.

# %% [markdown]
# outputs :
#
# less than 50% is equal to low salary
#
# more than 50% and less than 100% is medium salary
#
# more than 100% is considered as high salary and
#
# less than 0% is considered as no salary

# %%
conditions = [df['Salary'] /df['Base_pay'] * df['Age'] > 100, 
(df['Salary'] /df['Base_pay'] * df['Age'] <= 100) & (df['Salary'] /df['Base_pay'] * df['Age'] >= 50), (df['Salary'] /df['Base_pay'] * df['Age'] <= 49.999999999999999) & (df['Salary'] /df['Base_pay'] * df['Age'] > 0)]
outputs = ['high salary', 'medium salary', 'low salary']
df['salary_age_relation'] = np.select(conditions, outputs, 'no salary')
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
# here iam locating the no salary rows which are present in salary_age_relation column
df.loc[df['salary_age_relation']=='no salary']
# Out:
# Empty DataFrame
# Columns: [Gender, Business, Dependancies, Calls, Type, Billing, Rating, Age, Salary, Base_pay, Bonus, Unit_Price, Volume, openingbalance, closingbalance, low, Unit_Sales, Total_Sales, Months, Education, salary_age_relation]
# Index: []
#
# [0 rows x 21 columns]

# %%
# counting the values for salary_age_relation column
df['salary_age_relation'].value_counts()
# Out:
# high salary      4592
# medium salary     402
# low salary          6
# Name: salary_age_relation, dtype: int64

# %%
# using cross tab function for education and salary_age_relation
pd.crosstab(df.salary_age_relation,df.Education)
# pg education has the highest salary package consider to any other education type.
# Out:
# Education            Graduation  High School or less  Intermediate    PG
# salary_age_relation
# high salary                1794                    0             2  2796
# low salary                    3                    2             0     1
# medium salary               183                   12            25   182

# %%
# plotting the results
plt.figure(figsize=(14,7))
plt.title('Education wise salary comparision for staff members')
sns.countplot(df['Education'],hue=df.salary_age_relation)
# Out:
# <AxesSubplot:title={'center':'Education wise salary comparision for staff members'}, xlabel='Education', ylabel='count'>

# %% [markdown]
# # Finding the correlation between variables using spearman rank correlation.

# %% [markdown]
# Finding correlation between Salary and Age

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Salary)
y =(df.Age)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 4995    4996.0
# 4996    4997.0
# 4997    4998.0
# 4998    4999.0
# 4999    5000.0
# Name: Salary, Length: 5000, dtype: float64
# Rankings of Y:
# 0          1.5
# 1          4.0
# 2         20.5
# 3         13.5
# 4         27.0
#          ...
# 4995    4958.0
# 4996    4967.5
# 4997    4977.0
# 4998    4977.0
# 4999    4999.5
# Name: Age, Length: 5000, dtype: float64
# Spearman's Rank correlation: 0.20228180124819273

# %% [markdown]
# Finding correlation between Salary and Months

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Salary)
y =(df.Months)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 4995    4996.0
# 4996    4997.0
# 4997    4998.0
# 4998    4999.0
# 4999    5000.0
# Name: Salary, Length: 5000, dtype: float64
# Rankings of Y:
# 0          4.5
# 1          4.5
# 2          4.5
# 3          4.5
# 4        226.5
#          ...
# 4995    4866.0
# 4996    4866.0
# 4997    4866.0
# 4998    4866.0
# 4999    4866.0
# Name: Months, Length: 5000, dtype: float64
# Spearman's Rank correlation: 0.6037957593376555

# %% [markdown]
# Finding correlation between Salary and Base pay

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Salary)
y =(df.Base_pay)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 4995    4996.0
# 4996    4997.0
# 4997    4998.0
# 4998    4999.0
# 4999    5000.0
# Name: Salary, Length: 5000, dtype: float64
# Rankings of Y:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 4995    4992.5
# 4996    4997.0
# 4997    4998.0
# 4998    4999.0
# 4999    5000.0
# Name: Base_pay, Length: 5000, dtype: float64
# Spearman's Rank correlation: 0.9999759329652981

# %% [markdown]
# Finding correlation between Salary and Education

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Salary)
y =(df.Education)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 4995    4996.0
# 4996    4997.0
# 4997    4998.0
# 4998    4999.0
# 4999    5000.0
# Name: Salary, Length: 5000, dtype: float64
# Rankings of Y:
# 0       1987.5
# 1       1987.5
# 2       1987.5
# 3       1987.5
# 4       1987.5
#          ...
# 4995    3511.0
# 4996    3511.0
# 4997    3511.0
# 4998    3511.0
# 4999    3511.0
# Name: Education, Length: 5000, dtype: float64
# Spearman's Rank correlation: 0.2944187122592208

# %% [markdown]
# Finding correlation between Volume and Total sales

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Volume)
y =(df.Total_Sales)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0       4724.0
# 1       4288.0
# 2       4680.0
# 3       4951.0
# 4       4810.0
#          ...
# 4995    3053.5
# 4996    3696.0
# 4997    4027.0
# 4998    3043.0
# 4999    3689.0
# Name: Volume, Length: 5000, dtype: float64
# Rankings of Y:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#         ...
# 4995    29.5
# 4996    29.5
# 4997    29.5
# 4998    29.5
# 4999    29.5
# Name: Total_Sales, Length: 5000, dtype: float64
# Spearman's Rank correlation: -0.3906999409389804

# %% [markdown]
# Finding correlation between Unitprices and Unitsales

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Unit_Price)
y =(df.Unit_Sales)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0         33.0
# 1         32.0
# 2         34.0
# 3         36.0
# 4         35.0
#          ...
# 4995    5000.0
# 4996    4998.0
# 4997    4995.0
# 4998    4999.0
# 4999    4997.0
# Name: Unit_Price, Length: 5000, dtype: float64
# Rankings of Y:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          6.5
#          ...
# 4995    4996.0
# 4996    4997.5
# 4997    4997.5
# 4998    4999.0
# 4999    5000.0
# Name: Unit_Sales, Length: 5000, dtype: float64
# Spearman's Rank correlation: 0.8117348161447506

# %% [markdown]
# Finding correlation between Unitprice and Totalsales

# %%
import scipy.stats
 
# Two lists x and y
x =(df.Unit_Price)
y =(df.Total_Sales)
 
# Create a function that takes in x's and y's
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(x, y)
# Out:
# Rankings of X:
# 0         33.0
# 1         32.0
# 2         34.0
# 3         36.0
# 4         35.0
#          ...
# 4995    5000.0
# 4996    4998.0
# 4997    4995.0
# 4998    4999.0
# 4999    4997.0
# Name: Unit_Price, Length: 5000, dtype: float64
# Rankings of Y:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#         ...
# 4995    29.5
# 4996    29.5
# 4997    29.5
# 4998    29.5
# 4999    29.5
# Name: Total_Sales, Length: 5000, dtype: float64
# Spearman's Rank correlation: 0.800331485709647

# %%
# finding correlation for dataframe columns
# creating duplicate dataframe named as df1
df1=df.corr()

# %%
df1
# Out:
#                 Business       Age    Salary  Base_pay     Bonus  Unit_Price  \
# Business        1.000000 -0.005736 -0.008333 -0.008670 -0.008333    0.002512
# Age            -0.005736  1.000000  0.288743  0.288952  0.288743    0.191133
# Salary         -0.008333  0.288743  1.000000  0.999316  1.000000    0.596259
# Base_pay       -0.008670  0.288952  0.999316  1.000000  0.999316    0.598456
# Bonus          -0.008333  0.288743  1.000000  0.999316  1.000000    0.596259
# Unit_Price      0.002512  0.191133  0.596259  0.598456  0.596259    1.000000
# Volume          0.018296 -0.036265 -0.207246 -0.206826 -0.207246   -0.045986
# openingbalance -0.021919  0.110495  0.738209  0.738193  0.738209    0.481124
# closingbalance  0.005888  0.294936  0.316732  0.317743  0.316732    0.332721
# low             0.000226  0.253885  0.811943  0.814963  0.811943    0.832543
# Unit_Sales     -0.018623  0.186905  0.940854  0.939774  0.940854    0.521937
# ...

# %%
# plotting the heatmap using the results
# correlation between all different features will be presented
plt.figure(figsize=(14,10))
sns.heatmap(df1.corr(),annot=True,cmap="Reds")
# Out:
# <AxesSubplot:>

# %%
# using the dataframe columns i am trying to handel outliers so iam using boxplot function 
# volume column has more outliers.
df.boxplot(figsize=(20,18))
plt.savefig("df_box_plots")
plt.show()

# %% [markdown]
# # --- Establish a base line ---

# %%
# creating df2 using original dataframe
df2=df
df2
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
#select a reasonable metric (MSE in this case)
#create an extremely simple model and measure its efficiancy
#e.g. use "salary" for each industry as your model and then measure MSE

# %% [markdown]
# Having performed EDA and establishing that this is a regression problem, we know that we are to predict the continuous variable, Salary from the recently cleaned data (established correlated variables).
#
# We will now establish the predictor model by splitting the merged training dataset into training and testing data in a 80:20 ratio
#
# Simple Linear Regression is a method to help us understand the relationship between two variables:

# %% [markdown]
# # Splitting data into Training and Testing

# %%
# importing required library for train test split.
from sklearn.model_selection import train_test_split

# %% [markdown]
# dividing data into attributes and lables

# %%
# here we are taking x variable 
# and dropping some columns
# remaining undropped columns are more important consider to other columns in my point of view
x=df2.drop(df2.columns[[0,1,2,3,4,5,6,8,10,11,12,13,14,15,19,20]],axis=1)
x
# Out:
#       Age   Base_pay  Unit_Sales  Total_Sales  Months
# 0      18   2035.600       18.25        18.80       0
# 1      19   2279.248       18.40        18.85       0
# 2      22   2358.660       18.70        18.90       0
# 3      21   2450.048       18.75        19.00       0
# 4      23   2498.000       18.80        19.05       1
# ...   ...        ...         ...          ...     ...
# 4995   72  72278.720      117.80        19.45      72
# 4996   73  74274.360      118.60        19.45      72
# 4997   74  77054.720      118.60        19.45      72
# 4998   74  78388.280      118.65        19.45      72
# 4999   88  79988.296      118.75        19.45      72
#
# [5000 rows x 5 columns]

# %%
# here y variable is saalry column 
# why salary column is taken as y because the final agenda is to predict the salary. 
# and compare the actual salary vs predicted salary is varying by using ml algorithm
y=df2['Salary']
y.head()
# Out:
# 0    5089.00
# 1    5698.12
# 2    5896.65
# 3    6125.12
# 4    6245.00
# Name: Salary, dtype: float64

# %%
#Performing the split (Training - 80%, Testing - 20%)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

print("Number of training samples:",x_train.shape[0])
print("Number of test samples:",x_test.shape[0])
# Out:
# Number of training samples: 4000
# Number of test samples: 1000

# %% [markdown]
# # Training algorithm using Simple Linear Regression

# %%
# importing linear regression
from sklearn.linear_model import LinearRegression

#Creating Linear Regressor Object

L=LinearRegression()

# %%
#Fitting model using x and y attributes

L.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Making Prediction such that y_pred gives an array of Target Value (Salary)

y_pred=L.predict(x_test)

# %%
print("The first 5 predicted salaries: ",y_pred[0:5])
# Out:
# The first 5 predicted salaries:  [ 64560.94644476 118027.19868048 142692.22336535 133062.23228889
#   72921.13123642]

# %% [markdown]
# We now find the coefficients (a and b from the mathematical expression of Linear Regression)

# %%
#Finding intercept 'a' and slope 'b'
print("The Slope is: ", L.coef_)
print("The Intercept is: ", L.intercept_)
# Out:
# The Slope is:  [ 4.08860128  2.45217322 18.96223774 -0.13209789  5.65773007]
# The Intercept is:  529.9002142070822

# %%
#Having established a baseline model, we can predict Salaries in the test set

y_pred=L.predict(x_test) #Predicting the training data
y_pred
# Out:
# array([ 64560.94644476, 118027.19868048, 142692.22336535, 133062.23228889,
#         72921.13123642, 101328.77937603,  82536.43312292,  97527.27460567,
#         51905.56906079, 101053.81838195, 121383.39075612,  84279.34909551,
#        136250.69744278,  61746.84865003,  78516.09812352, 108930.68809096,
#         67944.37435358, 104580.44534208,  91768.44563246, 100265.50124596,
#         52692.07990884,  88813.80234961,  64640.40046775, 125173.71956141,
#        140040.75671172,  81651.14951669, 107480.39379691, 125130.34762492,
#        116373.05251568,  67050.38497618, 121694.40295465, 118396.20606519,
#        127908.6418633 ,  93570.97506527,  99639.80754395,  85442.43820935,
#        117279.01987049, 114732.86210163, 118923.74207405, 112114.17299165,
#        115341.29269202, 101405.71835372, 135449.58101734,  88890.83373607,
#         71945.10989633,  96770.71623549,  73790.22871468, 123453.18071494,
# ...

# %% [markdown]
# # Evaluating Model Accuracy using Metrics like MSE and R^2

# %% [markdown]
# When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.
#
# Two very important measures that are often used in Statistics to determine the accuracy of a model are:

# %% [markdown]
# # R^2 / R-squared Mean Squared Error (MSE)

# %% [markdown]
# R-squared :
#
# R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.
#
# The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.
#
# Mean Squared Error (MSE):
#
# The Mean Squared Error measures the average of the squares of errors, that is, the difference between actual value (y) and the estimated value (ŷ).
#
# Higher R^2 and lower MSE values are desirable

# %%
#Evaluation with MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error is: ", mse)

#Evaluation with R^2, which is a metric for model prediction accuracy
print('The R-square is: ', L.score(x,y))
# Out:
# Mean Squared Error is:  1525848.333330868
# The R-square is:  0.9986832291399949

# %%
#Prediction accuracy using 5-cross validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

Rcross = cross_val_score(L, x_train, y_train, cv = 5)

print("The k-cross validation accuracy is: ", (Rcross.mean(), Rcross.std()))
# Out:
# The k-cross validation accuracy is:  (0.9988625585948825, 0.0008780007456873327)

# %% [markdown]
# A distribution plot is an effective demonstration of how the predicted values of the training data are distributed

# %%
#Defining function for Distribution Plot
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 14
    height =10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Salary')
    plt.ylabel('Mean Values')
    plt.show()
    plt.close()

#Distribution plot for the 80% train data
Title = 'Distribution Plot of Actual Values vs. Predicted Values with Training Data'
DistributionPlot(y_train, y_pred,"Actual Values (Train)", "Predicted Values (Train)",Title)

# %% [markdown]
# red line represents Actual values(Train),
# blue line represents predicted values(Train)

# %% [markdown]
# Plots are nearly the same with the mean of predicted values slightly higher than the actual values

# %%
#Distribution plot for the 20% test data
##Predicting the first 5 values
y_pred_test = L.predict(x_test)
print("First 5 predictios: ", y_pred_test[0:5])
# Out:
# First 5 predictios:  [ 64560.94644476 118027.19868048 142692.22336535 133062.23228889
#   72921.13123642]

# %%
#Distribution plot for the 20% test data

Title = 'Distribution Plot of Actual Values vs. Predicted Values with Testing Data'
DistributionPlot(y_test, y_pred_test, "Actual Values (Test)", "Predicted Values (Test)", Title)

# %% [markdown]
# Plots are nearly the same with the mean of predicted values slightly equal the actual values

# %% [markdown]
# # We now have an MSE score of1525848.33 from our baseline model . How do we improve this score?

# %% [markdown]
# We can attempt to improve this score by comparing our baseline model against the following model -
#
# . Ridge Regression

# %% [markdown]
# # why specially Ridge regressions?

# %% [markdown]
# Ridge regression is a model tuning method that is used to analyse any data that suffers from multicollinearity. This method performs L2 regularization.
#
# The ridge regression are the same as that of linear regression: linearity, constant variance, and independence. However, as ridge regression does not provide confidence limits, the distribution of errors to be normal need not be assumed.

# %%
#Validating shapes of train and test sets
print("Feature Training Set Shape: ", x_train.shape)
print("Feature Testing Set Shape: ", x_test.shape)
print("Target Training Set Shape: ", y_train.shape)
print("Target Testing Set Shape: ", y_test.shape)
# Out:
# Feature Training Set Shape:  (4000, 5)
# Feature Testing Set Shape:  (1000, 5)
# Target Training Set Shape:  (4000,)
# Target Testing Set Shape:  (1000,)

# %% [markdown]
# # Ridge Regressor Algorithm

# %%
# importing the ridge library
from sklearn.linear_model import Ridge

# %%
#Creating Ridge regressor object
rg = Ridge(alpha = 1.0)
rg.fit(x_train, y_train)
rg.score(x_test, y_test)
# Out:
# 0.9976333898006988

# %%
#Predictng Training Salaries after applying Ridge Regression
y_pred_rtrain = rg.predict(x_train)
print("First 5 Salary Predictions on training data: ", y_pred_rtrain[0:5])
print("First 5 Actual Training Values: ", y_train[0:5].values)

#Comparing actual and predicted values with distribution plot
Title = 'Distribution Plot of Actual Values vs. Predicted Values'
DistributionPlot(y_train, y_pred_rtrain, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Out:
# First 5 Salary Predictions on training data:  [105631.57374939 110416.20715264  75910.00432075  56553.33714712
#   83946.76388518]
# First 5 Actual Training Values:  [105575.5673  110431.6375   76030.50206  56532.65239  83833.24462]

# %%
#Predictng Test Salaries after applying Ridge Regression
y_pred_rtest = rg.predict(x_test)
print("First 5 Salary Predictions on test data: ", y_pred_rtest[0:5])
print("First 5 Actual Test Values: ", y_test[0:5].values)

#Comparing actual and predicted values with distribution plot
Title = 'Distribution Plot of Actual Values vs. Predicted Values'
DistributionPlot(y_test, y_pred_rtest, "Actual Values (Test)", "Predicted Values (Test)", Title)
# Out:
# First 5 Salary Predictions on test data:  [ 64560.94726732 118027.19866529 142692.22400164 133062.23246661
#   72921.13212999]
# First 5 Actual Test Values:  [ 64631.43297 118137.1411  143137.3465  133346.5025   73049.7421 ]

# %%
#Evaluation with MSE
print("Training Data MSE: ", mean_squared_error(y_train, y_pred_rtrain))
print("Test Data MSE: ", mean_squared_error(y_test, y_pred_rtest))

#Evaluation with R^2, which is a metric for model prediction accuracy
print('Training Data R-square: ', rg.score(x_train, y_train))
print('Test Data R-square: ', rg.score(x_test, y_test))
# Out:
# Training Data MSE:  678310.3108665702
# Test Data MSE:  1525848.6432880964
# Training Data R-square:  0.9989461365728548
# Test Data R-square:  0.9976333898006988

# %% [markdown]
# # ---Select best model---

# %%
#select the model with the lowest error as your "production" model

print("MSE for Linear Regression: ", mse.round())
print("MSE for Ridge Regressor: ", mean_squared_error(y_train, y_pred_rtrain).round())
# Out:
# MSE for Linear Regression:  1525848.0
# MSE for Ridge Regressor:  678310.0

# %% [markdown]
# Thus, the ideal model for this dataset would be Ridge regressor

# %% [markdown]
# # --- How are you contributing to the organization ---

# %% [markdown]
# Based on my inputs and analysis how different features considered are affecting the salary component are
#
# . Age
#
# . Base_pay
#
# . Unit_sales
#
# . Total_sales
#
# . Months
#
# These column categories are very important and these are most considerable factors for salary component.
